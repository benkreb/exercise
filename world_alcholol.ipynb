# %%
import pandas as pd

# %%
data = pd.read_csv("world_alcohol.csv")

# %%
data.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %% [markdown]
# # Exercise 2

# %%
data['WHO region'].unique()
# Out:
# array(['Western Pacific', 'Americas', 'Africa', 'Eastern Mediterranean',
#        'Europe', 'South-East Asia'], dtype=object)

# %%
df_filtered = data[data['WHO region'].isin(["Africa ", "Eastern Mediterranean", "Europe"])]
df_filtered
# Out:
#     Year             WHO region  \
# 13  1984  Eastern Mediterranean
# 18  1984                 Europe
# 22  1984                 Europe
# 23  1984                 Europe
# 25  1984  Eastern Mediterranean
# 26  1985                 Europe
# 27  1984  Eastern Mediterranean
# 29  1986                 Europe
# 34  1986                 Europe
# 36  1987  Eastern Mediterranean
# 37  1986                 Europe
# 38  1987  Eastern Mediterranean
# 40  1987                 Europe
# 41  1986                 Europe
# 42  1984                 Europe
# 44  1985                 Europe
# 49  1986                 Europe
# 50  1985                 Europe
# 51  1987                 Europe
# 52  1986  Eastern Mediterranean
# 53  1984  Eastern Mediterranean
# 57  1989                 Europe
# 58  1984  Eastern Mediterranean
# 59  1989  Eastern Mediterranean
# 60  1987  Eastern Mediterranean
# 63  1985  Eastern Mediterranean
# 65  1989  Eastern Mediterranean
# 66  1987  Eastern Mediterranean
# ...

# %% [markdown]
# # Exercise 3

# %%
df_filtered1 = data[~data['WHO region'].isin(["Africa ", "Eastern Mediterranean", "Europe"])]
df_filtered1
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# 5   1987         Americas                              Guatemala
# 6   1987           Africa                              Mauritius
# 7   1985           Africa                                 Angola
# 8   1986         Americas                    Antigua and Barbuda
# 9   1984           Africa                                Nigeria
# 10  1987           Africa                               Botswana
# 11  1989         Americas                              Guatemala
# 12  1985  Western Pacific       Lao People's Democratic Republic
# ...

# %% [markdown]
# # Exercise 4

# %%
data[(data["Display Value"] > 0.5) & (data["Display Value"] < 2.5)]
# Out:
#     Year             WHO region  \
# 2   1985                 Africa
# 4   1987               Americas
# 8   1986               Americas
# 11  1989               Americas
# 17  1989                 Africa
# 18  1984                 Europe
# 19  1984                 Africa
# 26  1985                 Europe
# 27  1984  Eastern Mediterranean
# 32  1989                 Africa
# 34  1986                 Europe
# 35  1985               Americas
# 40  1987                 Europe
# 46  1987               Americas
# 48  1987               Americas
# 49  1986                 Europe
# 54  1984               Americas
# 64  1989               Americas
# 70  1986                 Africa
# 71  1985                 Africa
# 74  1986               Americas
# 79  1989                 Europe
# 80  1985                 Africa
# 82  1987                 Europe
# 86  1986               Americas
# 89  1986  Eastern Mediterranean
#
#                                               Country Beverage Types  \
# ...

# %% [markdown]
# # Exercise 5

# %%
data[(data["Display Value"] > 2) & (data["Beverage Types"] == "Wine")]
# Out:
#     Year WHO region      Country Beverage Types  Display Value
# 57  1989     Europe      Croatia           Wine           5.10
# 81  1985     Europe  Netherlands           Wine           2.54
# 96  1985     Europe   Luxembourg           Wine           7.38

# %% [markdown]
# # Exersize 6

# %%
data.iloc[0::10]
# Out:
#     Year             WHO region                     Country Beverage Types  \
# 0   1986        Western Pacific                    Viet Nam           Wine
# 10  1987                 Africa                    Botswana           Wine
# 20  1986        South-East Asia                     Myanmar           Wine
# 30  1986                 Africa                Sierra Leone          Other
# 40  1987                 Europe                     Austria        Spirits
# 50  1985                 Europe                 Switzerland          Other
# 60  1987  Eastern Mediterranean  Iran (Islamic Republic of)          Other
# 70  1986                 Africa                  Madagascar        Spirits
# 80  1985                 Africa                      Malawi          Other
# 90  1989                 Africa                      Malawi           Wine
#
#     Display Value
# 0            0.00
# 10           0.20
# 20           0.00
# 30           4.48
# 40           1.90
# 50           0.30
# ...

# %% [markdown]
# # Exercise 7

# %%
data.loc[:, 'WHO region':'Country'].head(10)
# Out:
#         WHO region                Country
# 0  Western Pacific               Viet Nam
# 1         Americas                Uruguay
# 2           Africa           Cte d'Ivoire
# 3         Americas               Colombia
# 4         Americas  Saint Kitts and Nevis
# 5         Americas              Guatemala
# 6           Africa              Mauritius
# 7           Africa                 Angola
# 8         Americas    Antigua and Barbuda
# 9           Africa                Nigeria

# %% [markdown]
# # Exercise 8

# %%
data.iloc[1::5]
# Out:
#     Year             WHO region  \
# 1   1986               Americas
# 6   1987                 Africa
# 11  1989               Americas
# 16  1984               Americas
# 21  1989               Americas
# 26  1985                 Europe
# 31  1986        Western Pacific
# 36  1987  Eastern Mediterranean
# 41  1986                 Europe
# 46  1987               Americas
# 51  1987                 Europe
# 56  1987        Western Pacific
# 61  1984        Western Pacific
# 66  1987  Eastern Mediterranean
# 71  1985                 Africa
# 76  1985                 Africa
# 81  1985                 Europe
# 86  1986               Americas
# 91  1989                 Europe
# 96  1985                 Europe
#
#                                               Country Beverage Types  \
# 1                                             Uruguay          Other
# 6                                           Mauritius           Wine
# ...

# %% [markdown]
# # Exercise 9

# %%
student_data = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth ': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},
    index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])
student_data.head(10)
# Out:
#    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
# S2        s002     V    Gino Mcneill     17/05/2002   12     192      32
# S3        s003    VI     Ryan Parkes     16/02/1999   13     186      33
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167      30
# S5        s002     V    Gino Mcneill     11/05/2002   14     151      31
# S6        s004    VI    David Parkes     15/09/1997   12     159      32
#
#     address
# S1  street1
# S2  street2
# S3  street3
# S4  street1
# S5  street2
# S6  street4

# %%
std_gb = student_data.groupby(['school_code'])

# %%
type(std_gb)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# # Exercise 10

# %%
std_gb = student_data.groupby(['school_code'])

# %%
std_gb.agg({"age": ["mean","max","min"]})
# Out:
#               age
#              mean max min
# school_code
# s001         12.5  13  12
# s002         13.0  14  12
# s003         13.0  13  13
# s004         12.0  12  12

# %% [markdown]
# # Exercise 11

# %%
student_data.groupby(['school_code', 'class'])
